# %% [markdown]
# <a href="https://www.kaggle.com/code/rishijmanna/retail-sales-eda?scriptVersionId=338233505" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
import numpy as np
import pandas as pd
import os
import kagglehub

# %%
df=pd.read_csv("/kaggle/input/datasets/rishijmanna/cleaned-retail-sales-dataset/cleaned_retail_sales_dataset.csv")

# %% [markdown]
# # Exploratary Data Analysis

# %% [markdown]
# # 1. Customer Demographics Analysis
#
# Understanding customer demographics helps businesses identify their target audience and develop effective marketing strategies. This section analyzes the distribution of customers based on their age and gender.

# %% [markdown]
# ## 1.1 Customer Age Distribution
#
# ### Objective
#
# To analyze the distribution of customer ages and identify the dominant age groups within the retail customer base.

# %%
import plotly.express as px

fig = px.histogram(
    df,
    x="age",
    nbins=15,
    marginal="box",
    title="Customer Age Distribution",
    opacity=0.85,
    color_discrete_sequence=["#1f77b4"]
)

fig.update_layout(
    template="plotly_white",
    xaxis_title="Age",
    yaxis_title="Number of Customers",
    hovermode="x unified",
    title_x=0.5
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### Observation
#
# - The age distribution illustrates how customers are spread across different age groups.
# - The histogram helps identify the most common customer age range.
# - The KDE curve provides an overview of the overall distribution pattern.
# - These insights help businesses understand the dominant customer demographic.

# %% [markdown]
# ## 1.2 Customer Gender Distribution
#
# ### Objective
#
# To analyze the gender composition of customers and determine the proportion of male, female, and other customers.

# %%
gender_counts = (
    df["gender"]
    .value_counts()
    .reset_index()
)

gender_counts.columns = ["Gender", "Count"]

fig = px.pie(
    gender_counts,
    names="Gender",
    values="Count",
    hole=0.4,
    title="Customer Gender Distribution"
)

fig.update_traces(
    textposition="inside",
    textinfo="percent+label",
    hovertemplate="<b>%{label}</b><br>Customers: %{value}<br>Percentage: %{percent}"
)

fig.update_layout(
    template="plotly_white",
    title_x=0.5
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### Observation
#
# - The pie chart illustrates the proportion of customers across different gender categories.
# - It helps identify the dominant customer segment.
# - Understanding gender distribution assists in designing targeted marketing campaigns and customer engagement strategies.

# %% [markdown]
# # 2. Geographic Analysis
#
# Geographic analysis helps identify the regions and cities contributing the most to retail sales. Understanding customer distribution across locations enables businesses to optimize marketing efforts, logistics, and inventory management.

# %% [markdown]
# ## 2.1 Region-wise Customer Distribution
#
# ### Objective
#
# To identify the distribution of customers across different geographical regions.

# %%
import plotly.express as px

region_count = (
    df["region"]
    .value_counts()
    .reset_index()
)

region_count.columns = ["Region", "Customers"]

fig = px.bar(
    region_count,
    x="Region",
    y="Customers",
    color="Customers",
    text="Customers",
    title="Region-wise Customer Distribution"
)

fig.update_traces(
    textposition="outside",
    hovertemplate="<b>%{x}</b><br>Total Customers: %{y}<extra></extra>"
)

fig.update_layout(
    template="plotly_white",
    title_x=0.5,
    xaxis_title="Region",
    yaxis_title="Number of Customers",
    hovermode="x unified",
    coloraxis_showscale=False
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### Observation
#
# - The visualization displays the number of customers belonging to each region.
# - Regions with a larger customer base may contribute significantly to overall sales.
# - Businesses can use this information to prioritize regional marketing strategies.

# %% [markdown]
# ## 2.2 Top 10 Cities by Customer Count
#
# ### Objective
#
# The objective of this analysis is to identify the cities with the highest number of customers. Understanding customer concentration across cities enables businesses to prioritize marketing efforts and improve regional business performance.

# %% [markdown]
# city_count = (
#     df["city"]
#     .value_counts()
#     .head(10)
#     .reset_index()
# )
#
# city_count.columns = ["City", "Customers"]
#
# fig = px.bar(
#     city_count,
#     x="Customers",
#     y="City",
#     orientation="h",
#     color="Customers",
#     text="Customers",
#     title="Top 10 Cities by Customer Count"
# )
#
# fig.update_traces(
#     textposition="outside",
#     hovertemplate="<b>%{y}</b><br>Customers: %{x}<extra></extra>"
# )
#
# fig.update_layout(
#     template="plotly_white",
#     title_x=0.5,
#     xaxis_title="Number of Customers",
#     yaxis_title="City",
#     yaxis=dict(categoryorder="total ascending"),
#     coloraxis_showscale=False
# )
#
# fig.show()

# %% [markdown]
# ### Observation
#
# - The chart ranks the top 10 cities based on customer count.
# - Interactive tooltips display the exact number of customers for each city.
# - Cities with the highest customer concentration represent major business hubs and can be prioritized for targeted marketing campaigns, inventory allocation, and customer service improvements.

# %% [markdown]
# #  3. Product Analysis
#
# Product analysis helps evaluate customer purchasing behavior and product performance. By examining product categories, best-selling products, and category-wise sales, businesses can identify high-performing products, optimize inventory management, and improve pricing and promotional strategies.
#
# This section presents interactive visualizations to analyze product performance across different dimensions.

# %% [markdown]
# ## 3.1 Product Category Distribution
#
# ### Objective
#
# The objective of this analysis is to examine the distribution of products across different categories. Understanding category distribution helps businesses identify the most popular product segments and allocate inventory more effectively.

# %%
import plotly.express as px

category_count = (
    df["product_category"]
    .value_counts()
    .reset_index()
)

category_count.columns = ["Category", "Products"]

fig = px.bar(
    category_count,
    x="Category",
    y="Products",
    color="Products",
    text="Products",
    title="Product Category Distribution"
)

fig.update_traces(
    textposition="outside",
    hovertemplate="<b>%{x}</b><br>Products Sold: %{y}<extra></extra>"
)

fig.update_layout(
    template="plotly_white",
    title_x=0.5,
    xaxis_title="Product Category",
    yaxis_title="Number of Orders",
    hovermode="x unified",
    coloraxis_showscale=False
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### Observation
#
# - The chart displays the number of orders for each product category.
# - Hovering over each bar reveals the exact number of orders.
# - Categories with higher order counts indicate greater customer demand and may require larger inventory allocation.
# - The results help identify the most popular product segments.

# %% [markdown]
# ## 3.2 Top 10 Best-Selling Products
#
# ### Objective
#
# The objective of this analysis is to identify the products with the highest number of customer orders. This helps businesses understand customer preferences and prioritize high-demand products.

# %%
top_products = (
    df["product_name"]
    .value_counts()
    .head(10)
    .reset_index()
)

top_products.columns = ["Product", "Orders"]

fig = px.bar(
    top_products,
    x="Orders",
    y="Product",
    orientation="h",
    color="Orders",
    text="Orders",
    title="Top 10 Best-Selling Products"
)

fig.update_traces(
    textposition="outside",
    hovertemplate="<b>%{y}</b><br>Orders: %{x}<extra></extra>"
)

fig.update_layout(
    template="plotly_white",
    title_x=0.5,
    xaxis_title="Number of Orders",
    yaxis_title="Product",
    yaxis=dict(categoryorder="total ascending"),
    coloraxis_showscale=False
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### Observation
#
# - The chart ranks the top 10 products based on the number of customer orders.
# - Interactive tooltips display the exact number of orders for each product.
# - High-performing products contribute significantly to sales and should be prioritized for inventory management and promotional campaigns.

# %% [markdown]
# ## 3.3 Category-wise Sales Performance
#
# ### Objective
#
# The objective of this analysis is to compare the total sales generated by each product category. This helps identify the categories contributing the most to overall business revenue.

# %%
category_sales = (
    df.groupby("product_category", as_index=False)["sales_amount"]
      .sum()
      .sort_values("sales_amount", ascending=False)
)

fig = px.bar(
    category_sales,
    x="product_category",
    y="sales_amount",
    color="sales_amount",
    text_auto=".2s",
    title="Total Sales by Product Category"
)

fig.update_traces(
    hovertemplate="<b>%{x}</b><br>Total Sales: ₹%{y:,.2f}<extra></extra>"
)

fig.update_layout(
    template="plotly_white",
    title_x=0.5,
    xaxis_title="Product Category",
    yaxis_title="Total Sales (₹)",
    hovermode="x unified",
    coloraxis_showscale=False
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### Observation
#
# - The visualization compares the total revenue generated by each product category.
# - Hovering over each bar displays the exact sales amount.
# - Categories with higher sales contribute more significantly to overall business revenue.
# - This analysis supports pricing strategies, inventory planning, and future product investment decisions.

# %% [markdown]
# # 4. Sales Performance Analysis
#
# Sales performance analysis evaluates how revenue is generated across different time periods, customer segments, and geographical locations. Analyzing sales trends helps businesses identify peak sales periods, monitor business growth, evaluate regional performance, and recognize high-value customers.
#
# This section presents interactive visualizations to explore sales patterns and identify key revenue-generating factors.

# %% [markdown]
# ## 4.1 Sales Amount Distribution
#
# ### Objective
#
# The objective of this analysis is to understand the distribution of sales amounts across all transactions. This helps identify common purchase values, sales variability, and the presence of high-value transactions.

# %% [markdown]
# import plotly.express as px
#
# fig = px.histogram(
#     df,
#     x="sales_amount",
#     nbins=30,
#     marginal="box",
#     title="Distribution of Sales Amount",
#     color_discrete_sequence=["#2E86C1"]
# )
#
# fig.update_layout(
#     template="plotly_white",
#     title_x=0.5,
#     xaxis_title="Sales Amount (₹)",
#     yaxis_title="Number of Orders",
#     hovermode="x unified"
# )
#
# fig.show()

# %% [markdown]
# ### Observation
#
# - The histogram displays the frequency distribution of sales amounts.
# - The box plot highlights the median, quartiles, and possible high-value transactions.
# - Hovering over the histogram bars displays the exact number of orders within each sales range.
# - This analysis helps identify customer spending behavior and sales variability.

# %% [markdown]
# ## 4.2 Monthly Sales Trend
#
# ### Objective
#
# The objective of this analysis is to examine monthly sales performance and identify seasonal trends or fluctuations in revenue over time.

# %%
print(df["order_date"].dtype)
# Out:
# object

# %%
df["order_date"] = pd.to_datetime(
    df["order_date"],
    format="mixed",
    dayfirst=True,
    errors="coerce"
)

# %%
print(df["order_date"].dtype)
# Out:
# datetime64[ns]

# %%
print(df["order_date"].isna().sum())
# Out:
# 0

# %%
monthly_sales = (
    df.groupby(df["order_date"].dt.to_period("M"))["sales_amount"]
      .sum()
      .reset_index()
)

monthly_sales["order_date"] = monthly_sales["order_date"].astype(str)

fig = px.line(
    monthly_sales,
    x="order_date",
    y="sales_amount",
    markers=True,
    title="Monthly Sales Trend"
)

fig.update_traces(
    hovertemplate="<b>%{x}</b><br>Total Sales: ₹%{y:,.2f}<extra></extra>"
)

fig.update_layout(
    template="plotly_white",
    title_x=0.5,
    xaxis_title="Month",
    yaxis_title="Total Sales (₹)",
    hovermode="x unified"
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### Observation
#
# - The line chart illustrates monthly sales performance throughout the dataset.
# - Interactive markers display the exact sales amount for each month.
# - Peaks indicate high-performing months, while dips may represent slower business periods.
# - Understanding these trends supports sales forecasting and seasonal planning.

# %% [markdown]
# ## 4.3 Region-wise Sales Performance
#
# ### Objective
#
# The objective of this analysis is to compare the total sales generated by different regions and identify the highest revenue-contributing markets.

# %%
region_sales = (
    df.groupby("region", as_index=False)["sales_amount"]
      .sum()
      .sort_values("sales_amount", ascending=False)
)

fig = px.bar(
    region_sales,
    x="region",
    y="sales_amount",
    color="sales_amount",
    text_auto=".2s",
    title="Region-wise Total Sales"
)

fig.update_traces(
    hovertemplate="<b>%{x}</b><br>Total Sales: ₹%{y:,.2f}<extra></extra>"
)

fig.update_layout(
    template="plotly_white",
    title_x=0.5,
    xaxis_title="Region",
    yaxis_title="Total Sales (₹)",
    hovermode="x unified",
    coloraxis_showscale=False
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### Observation
#
# - The chart compares total sales generated by each region.
# - Interactive hover tooltips display the exact sales value for every region.
# - Regions generating higher revenue represent strong business markets and may warrant increased investment and operational focus.

# %% [markdown]
# ## 4.4 Top 10 Customers by Sales
#
# ### Objective
#
# The objective of this analysis is to identify customers who contribute the highest sales revenue. Recognizing high-value customers helps businesses strengthen customer relationships and develop loyalty programs.

# %%
top_customers = (
    df.groupby("customer_name", as_index=False)["sales_amount"]
      .sum()
      .sort_values("sales_amount", ascending=False)
      .head(10)
)

fig = px.bar(
    top_customers,
    x="sales_amount",
    y="customer_name",
    orientation="h",
    color="sales_amount",
    text_auto=".2s",
    title="Top 10 Customers by Total Sales"
)

fig.update_traces(
    hovertemplate="<b>%{y}</b><br>Total Sales: ₹%{x:,.2f}<extra></extra>"
)

fig.update_layout(
    template="plotly_white",
    title_x=0.5,
    xaxis_title="Total Sales (₹)",
    yaxis_title="Customer Name",
    yaxis=dict(categoryorder="total ascending"),
    hovermode="y unified",
    coloraxis_showscale=False
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### Observation
#
# - The chart ranks the top 10 customers based on total purchase value.
# - Hovering over each bar reveals the exact revenue generated by each customer.
# - High-value customers are important assets for the business and can be targeted through loyalty programs, personalized offers, and premium services.

# %% [markdown]
# # 5 Profitability Analysis
#
# Profitability analysis evaluates the financial performance of the business by examining the profit generated from sales transactions. While sales revenue indicates business volume, profit reflects the actual earnings after costs. This analysis helps identify profitable product categories, regions, and customer segments, enabling better pricing, inventory, and business strategies.
#
# This section uses interactive visualizations to analyze profit distribution and identify the key factors influencing business profitability.

# %% [markdown]
# ## 5.1 Profit Distribution
#
# ### Objective
#
# The objective of this analysis is to examine the distribution of profits across all sales transactions. This helps identify the range of profits, detect highly profitable transactions, and understand the overall profitability pattern of the business.

# %%
import plotly.express as px

fig = px.histogram(
    df,
    x="profit",
    nbins=30,
    marginal="box",
    title="Profit Distribution",
    color_discrete_sequence=["#2ca02c"]
)

fig.update_layout(
    template="plotly_white",
    title_x=0.5,
    xaxis_title="Profit (₹)",
    yaxis_title="Number of Orders",
    hovermode="x unified"
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### Observation
#
# - The histogram illustrates the distribution of profit values across all transactions.
# - The box plot summarizes the spread of profits and highlights potential outliers.
# - Hovering over each bar displays the exact number of transactions within each profit range.
# - This analysis helps evaluate the consistency and variability of business profitability.

# %% [markdown]
# ## 5.2 Profit by Product Category
#
# ### Objective
#
# The objective of this analysis is to compare the total profit generated by each product category. This helps identify the most profitable product segments and supports inventory and pricing decisions.

# %%
category_profit = (
    df.groupby("product_category", as_index=False)["profit"]
      .sum()
      .sort_values("profit", ascending=False)
)

fig = px.bar(
    category_profit,
    x="product_category",
    y="profit",
    color="profit",
    text_auto=".2s",
    title="Profit by Product Category"
)

fig.update_traces(
    hovertemplate="<b>%{x}</b><br>Total Profit: ₹%{y:,.2f}<extra></extra>"
)

fig.update_layout(
    template="plotly_white",
    title_x=0.5,
    xaxis_title="Product Category",
    yaxis_title="Total Profit (₹)",
    hovermode="x unified",
    coloraxis_showscale=False
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### Observation
#
# - The chart compares the total profit generated by each product category.
# - Hover tooltips display the exact profit earned by each category.
# - Product categories with higher profits contribute more significantly to business growth.
# - These insights support product portfolio optimization and pricing strategies.

# %% [markdown]
# ## 5.3 Region-wise Profit Analysis
#
# ### Objective
#
# The objective of this analysis is to evaluate profit performance across different regions and identify the most profitable geographical markets.

# %%
region_profit = (
    df.groupby("region", as_index=False)["profit"]
      .sum()
      .sort_values("profit", ascending=False)
)

fig = px.bar(
    region_profit,
    x="region",
    y="profit",
    color="profit",
    text_auto=".2s",
    title="Region-wise Profit"
)

fig.update_traces(
    hovertemplate="<b>%{x}</b><br>Total Profit: ₹%{y:,.2f}<extra></extra>"
)

fig.update_layout(
    template="plotly_white",
    title_x=0.5,
    xaxis_title="Region",
    yaxis_title="Total Profit (₹)",
    hovermode="x unified",
    coloraxis_showscale=False
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### Observation
#
# - The visualization compares the total profit generated by each region.
# - Hovering over each bar reveals the exact profit earned.
# - Highly profitable regions represent strong markets and may benefit from further business expansion and investment.

# %% [markdown]
# ## 5.4 Product Category vs Sales Amount and Profit
#
# ### Objective
#
# The objective of this analysis is to compare the total sales amount and total profit generated by each product category. This visualization helps identify product categories that generate high revenue as well as high profitability, enabling better inventory planning and business decision-making.

# %%
import plotly.express as px

category_summary = (
    df.groupby("product_category", as_index=False)
      .agg({
          "sales_amount": "sum",
          "profit": "sum"
      })
)

# Convert to long format for grouped bar chart
category_summary = category_summary.melt(
    id_vars="product_category",
    value_vars=["sales_amount", "profit"],
    var_name="Metric",
    value_name="Amount"
)

# Rename legend labels
category_summary["Metric"] = category_summary["Metric"].replace({
    "sales_amount": "Sales Amount",
    "profit": "Profit"
})

fig = px.bar(
    category_summary,
    x="product_category",
    y="Amount",
    color="Metric",
    barmode="group",
    text_auto=".2s",
    title="Product Category vs Sales Amount and Profit"
)

fig.update_traces(
    hovertemplate="<b>%{x}</b><br>%{fullData.name}: ₹%{y:,.2f}<extra></extra>"
)

fig.update_layout(
    template="plotly_white",
    title_x=0.5,
    xaxis_title="Product Category",
    yaxis_title="Amount (₹)",
    legend_title="Metric",
    hovermode="x unified"
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### Observation
#
# - The grouped bar chart compares the total sales amount and total profit generated by each product category.
# - Hovering over the bars displays the exact sales and profit values for each category.
# - Categories with both high sales and high profit represent the strongest performing product segments.
# - Differences between sales and profit help identify categories with lower profit margins despite generating high revenue.

# %% [markdown]
# # 6. Customer Behavior & Operational Analysis
#
# Customer behavior and operational performance are critical factors that influence overall business success. Analyzing payment preferences, shipping performance, customer satisfaction, product returns, and order status helps organizations improve operational efficiency, enhance customer experience, and optimize business processes.
#
# This section presents interactive visualizations to explore customer preferences and evaluate operational performance.

# %% [markdown]
# ## 6.1 Payment Method Distribution
#
# ### Objective
#
# The objective of this analysis is to identify the most preferred payment methods used by customers. Understanding payment preferences helps businesses optimize payment options and improve customer convenience.

# %%
import plotly.express as px

payment_count = (
    df["payment_method"]
    .value_counts()
    .reset_index()
)

payment_count.columns = ["Payment Method", "Orders"]

fig = px.pie(
    payment_count,
    names="Payment Method",
    values="Orders",
    hole=0.45,
    title="Payment Method Distribution"
)

fig.update_traces(
    textinfo="percent+label",
    hovertemplate="<b>%{label}</b><br>Orders: %{value}<br>Percentage: %{percent}<extra></extra>"
)

fig.update_layout(
    template="plotly_white",
    title_x=0.5
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### Observation
#
# - The chart illustrates the proportion of orders placed using different payment methods.
# - Hovering over each slice displays the exact number of orders and percentage contribution.
# - The most preferred payment methods indicate customer payment behavior and can help businesses optimize payment gateway support.

# %% [markdown]
# ## 6.2 Shipping Performance Analysis
#
# ### Objective
#
# The objective of this analysis is to evaluate delivery performance by examining the number of days required to ship customer orders.

# %%
fig = px.histogram(
    df,
    x="days_to_ship",
    nbins=10,
    marginal="box",
    title="Distribution of Shipping Time",
    color_discrete_sequence=["#F39C12"]
)

fig.update_layout(
    template="plotly_white",
    title_x=0.5,
    xaxis_title="Days to Ship",
    yaxis_title="Number of Orders",
    hovermode="x unified"
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### Observation
#
# - The histogram shows how many days were required to ship customer orders.
# - The box plot summarizes the shipping time distribution and highlights any unusual delivery durations.
# - This analysis helps evaluate delivery efficiency and identify opportunities for logistics improvement.

# %% [markdown]
# ## 6.3 Average Shipping Cost by Region
#
# ### Objective
#
# The objective of this analysis is to compare the average shipping cost across different regions and identify regional differences in logistics expenses.

# %%
shipping_region = (
    df.groupby("region", as_index=False)["shipping_cost"]
      .mean()
      .sort_values("shipping_cost", ascending=False)
)

fig = px.bar(
    shipping_region,
    x="region",
    y="shipping_cost",
    color="shipping_cost",
    text_auto=".2f",
    title="Average Shipping Cost by Region"
)

fig.update_traces(
    hovertemplate="<b>%{x}</b><br>Average Shipping Cost: ₹%{y:.2f}<extra></extra>"
)

fig.update_layout(
    template="plotly_white",
    title_x=0.5,
    xaxis_title="Region",
    yaxis_title="Average Shipping Cost (₹)",
    hovermode="x unified",
    coloraxis_showscale=False
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### Observation
#
# - The chart compares the average shipping cost across different regions.
# - Regions with higher shipping costs may require logistics optimization or revised pricing strategies.
# - Interactive tooltips display the exact average shipping cost for each region.

# %% [markdown]
# ## 6.4 Customer Satisfaction Distribution
#
# ### Objective
#
# The objective of this analysis is to examine customer satisfaction ratings and evaluate the overall customer experience.

# %%
import plotly.express as px

# Count satisfaction ratings
satisfaction_counts = (
    df["customer_satisfaction"]
    .value_counts()
    .sort_index()
    .reset_index()
)

satisfaction_counts.columns = ["Rating", "Customers"]

# Create bar chart with different colors
fig = px.bar(
    satisfaction_counts,
    x="Rating",
    y="Customers",
    color="Rating",
    text="Customers",
    title="Customer Satisfaction Distribution",
    color_discrete_sequence=px.colors.qualitative.Set2
)

fig.update_traces(
    textposition="outside",
    hovertemplate="<b>Rating:</b> %{x}<br><b>Customers:</b> %{y}<extra></extra>"
)

fig.update_layout(
    template="plotly_white",
    title_x=0.5,
    xaxis_title="Customer Satisfaction Rating",
    yaxis_title="Number of Customers",
    showlegend=False
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### Observation
#
# - The visualization displays the distribution of customer satisfaction ratings.
# - Hovering over each bar provides the exact number of customers for each rating.
# - Higher ratings indicate positive customer experiences, while lower ratings may highlight areas requiring service improvement.

# %% [markdown]
# ## 6.5 Product Return Analysis
#
# ### Objective
#
# The objective of this analysis is to examine the proportion of returned and non-returned products. Understanding return patterns helps businesses improve product quality, customer satisfaction, and return management strategies.

# %%
return_count = (
    df["return_flag"]
    .value_counts()
    .reset_index()
)

return_count.columns = ["Return Status", "Orders"]

fig = px.pie(
    return_count,
    names="Return Status",
    values="Orders",
    hole=0.45,
    title="Product Return Distribution"
)

fig.update_traces(
    textinfo="percent+label",
    hovertemplate="<b>%{label}</b><br>Orders: %{value}<br>Percentage: %{percent}<extra></extra>"
)

fig.update_layout(
    template="plotly_white",
    title_x=0.5
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### Observation
#
# - The chart compares returned and non-returned orders.
# - Hover tooltips display the exact number of returned and non-returned products.
# - A low return percentage generally indicates better product quality and customer satisfaction.

# %% [markdown]
# ## 6.6 Order Status Distribution
#
# ### Objective
#
# The objective of this analysis is to evaluate the distribution of different order statuses, providing insights into order fulfillment efficiency and operational performance.

# %% [markdown]
# # 7. Correlation & Relationship Analysis
#
# Correlation analysis helps identify relationships among numerical variables in the dataset. Understanding these relationships enables businesses to determine which factors influence sales, profit, shipping costs, customer satisfaction, and overall business performance.
#
# This section uses interactive visualizations to examine correlations and relationships between important business variables.

# %% [markdown]
# ## 7.1 Correlation Matrix
#
# ### Objective
#
# The objective of this analysis is to measure the strength and direction of relationships among numerical variables. Correlation analysis helps identify variables that positively or negatively influence business performance.

# %%
import plotly.express as px

corr = df.select_dtypes(include=["number"]).corr()

fig = px.imshow(
    corr,
    text_auto=".2f",
    aspect="auto",
    color_continuous_scale="RdBu_r",
    title="Correlation Matrix of Numerical Features"
)

fig.update_layout(
    template="plotly_white",
    title_x=0.5
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### Observation
#
# - The heatmap illustrates the correlation among all numerical variables.
# - Positive values indicate a direct relationship, whereas negative values indicate an inverse relationship.
# - Stronger correlations may reveal variables that significantly influence sales and profitability.
# - Hovering over each cell displays the exact correlation coefficient.

# %% [markdown]
# ## 7.2 Quantity vs Sales Amount
#
# ### Objective
#
# To analyze how the quantity of purchased products influences the total sales amount.

# %%
fig = px.scatter(
    df,
    x="quantity",
    y="sales_amount",
    color="product_category",
    trendline="ols",
    hover_data=["customer_name", "product_name"],
    title="Quantity vs Sales Amount"
)

fig.update_layout(
    template="plotly_white",
    title_x=0.5,
    xaxis_title="Quantity",
    yaxis_title="Sales Amount (₹)"
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### Observation
#
# - The scatter plot illustrates the relationship between purchased quantity and sales amount.
# - A positive trend generally indicates that larger purchase quantities contribute to higher sales.
# - Hover tooltips provide transaction-level details for further exploration.

# %% [markdown]
# ## 7.3 Discount Percentage vs Sales Amount
#
# ### Objective
#
# To evaluate whether higher discounts contribute to increased sales.

# %%
fig = px.scatter(
    df,
    x="discount_pct",
    y="sales_amount",
    color="product_category",
    trendline="ols",
    hover_data=["product_name"],
    title="Discount Percentage vs Sales Amount"
)

fig.update_layout(
    template="plotly_white",
    title_x=0.5,
    xaxis_title="Discount (%)",
    yaxis_title="Sales Amount (₹)"
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### Observation
#
# - The visualization explores the relationship between discount percentage and sales amount.
# - Trendline analysis helps determine whether discounts positively influence revenue generation.

# %% [markdown]
# ## 25. Discount Percentage vs Profit
#
# ### Objective
#
# To examine how discount strategies affect business profitability.

# %%
fig = px.box(
    df,
    x="customer_satisfaction",
    y="profit",
    color="customer_satisfaction",
    title="Customer Satisfaction vs Profit"
)

fig.update_layout(
    template="plotly_white",
    title_x=0.5,
    xaxis_title="Customer Satisfaction",
    yaxis_title="Profit (₹)"
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### Observation
#
# - The box plot compares profit distributions across different customer satisfaction ratings.
# - Variations in profit across ratings help evaluate whether customer satisfaction contributes to business profitability.

# %% [markdown]
# # Key Business Insights
#
# Based on the exploratory data analysis, the following important business insights were identified:
#
# 1. Customer demographics reveal the dominant age group and gender contributing to retail sales.
#
# 2. Certain regions and cities contribute significantly more customers and revenue than others.
#
# 3. Product categories differ considerably in both sales volume and profitability.
#
# 4. A small number of products account for a substantial portion of total sales.
#
# 5. Monthly sales trends indicate fluctuations that may reflect seasonal demand.
#
# 6. High sales do not always result in proportionally high profits, highlighting the importance of profit margin analysis.
#
# 7. Payment method preferences indicate customer purchasing behavior and can guide payment infrastructure improvements.
#
# 8. Shipping costs and delivery times vary across regions, suggesting opportunities for logistics optimization.
#
# 9. Customer satisfaction ratings provide valuable indicators of service quality and customer experience.
#
# 10. Product return patterns can help identify quality issues and improve inventory management.
#
# 11. Correlation analysis reveals relationships among sales, profit, discounts, and other numerical variables, supporting data-driven business decisions.

# %% [markdown]
# # Executive Business Summary
#
# The Executive Business Summary provides a concise overview of the key performance indicators (KPIs) derived from the retail sales dataset. These metrics summarize the overall business performance, customer behavior, sales trends, profitability, and operational efficiency.
#
# The dashboard below presents the most important business metrics that can assist decision-makers in evaluating the organization's overall performance at a glance.

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# ============================
# Calculate KPIs
# ============================

total_orders = len(df)

total_sales = df["sales_amount"].sum()

total_profit = df["profit"].sum()

average_order_value = df["sales_amount"].mean()

average_shipping_days = df["days_to_ship"].mean()

average_satisfaction = df["customer_satisfaction"].mean()

return_rate = (
    (df["return_flag"] == "Yes").sum()
    / len(df)
) * 100

# ============================
# KPI Dashboard
# ============================

fig = make_subplots(
    rows=2,
    cols=3,
    specs=[
        [{"type":"indicator"},{"type":"indicator"},{"type":"indicator"}],
        [{"type":"indicator"},{"type":"indicator"},{"type":"indicator"}]
    ]
)

fig.add_trace(
    go.Indicator(
        mode="number",
        title={"text":"<b>Total Orders</b>"},
        value=total_orders
    ),
    row=1,col=1
)

fig.add_trace(
    go.Indicator(
        mode="number",
        title={"text":"<b>Total Sales (₹)</b>"},
        value=total_sales,
        number={"prefix":"₹","valueformat":",.2f"}
    ),
    row=1,col=2
)

fig.add_trace(
    go.Indicator(
        mode="number",
        title={"text":"<b>Total Profit (₹)</b>"},
        value=total_profit,
        number={"prefix":"₹","valueformat":",.2f"}
    ),
    row=1,col=3
)

fig.add_trace(
    go.Indicator(
        mode="number",
        title={"text":"<b>Average Order Value (₹)</b>"},
        value=average_order_value,
        number={"prefix":"₹","valueformat":",.2f"}
    ),
    row=2,col=1
)

fig.add_trace(
    go.Indicator(
        mode="number",
        title={"text":"<b>Average Shipping Time</b>"},
        value=average_shipping_days,
        number={"suffix":" Days","valueformat":".2f"}
    ),
    row=2,col=2
)

fig.add_trace(
    go.Indicator(
        mode="number",
        title={"text":"<b>Average Satisfaction</b>"},
        value=average_satisfaction,
        number={"suffix":" / 5","valueformat":".2f"}
    ),
    row=2,col=3
)

fig.update_layout(
    title="Executive Business Dashboard",
    template="plotly_white",
    height=600
)

fig.show()

print(f"Return Rate : {return_rate:.2f}%")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## Executive Summary
#
# The executive dashboard highlights the overall business performance using key performance indicators derived from the retail sales dataset.
#
# ### Summary
#
# - The dataset contains all processed retail transactions used for the analysis.
# - The total sales and total profit represent the overall financial performance of the business.
# - The average order value provides insights into customer purchasing behavior.
# - Average shipping time reflects delivery efficiency.
# - Customer satisfaction indicates the overall service quality experienced by customers.
# - The return rate measures the percentage of products returned and serves as an important indicator of product quality and customer satisfaction.
#
# These KPIs provide a quick overview of business performance and support data-driven decision-making.

# %% [markdown]
# # Business Recommendations
#
# Based on the exploratory data analysis, the following recommendations are proposed to improve business performance:
#
# 1. Increase inventory levels for high-performing product categories to avoid stock shortages.
#
# 2. Focus marketing campaigns on regions and cities that generate the highest sales and profits.
#
# 3. Re-evaluate pricing and discount strategies for categories with high sales but relatively low profit margins.
#
# 4. Optimize shipping operations in regions with higher delivery costs and longer shipping times.
#
# 5. Introduce customer loyalty programs to retain high-value customers and encourage repeat purchases.
#
# 6. Monitor customer satisfaction regularly and address recurring service-related issues to improve customer experience.
#
# 7. Investigate the reasons behind returned products and implement quality control measures to reduce return rates.
#
# 8. Promote the most preferred payment methods to provide a smoother purchasing experience.
#
# 9. Analyze seasonal sales trends to improve demand forecasting and inventory planning.
#
# 10. Continue using data-driven decision-making to optimize operational efficiency and profitability.

# %% [markdown]
# # Final Conclusion
#
# This project successfully transformed a raw retail sales dataset into meaningful business intelligence through systematic data cleaning, preprocessing, exploratory data analysis, and interactive visualization.
#
# The analysis revealed valuable insights into customer demographics, product performance, regional sales, profitability, shipping efficiency, payment preferences, customer satisfaction, and return behavior. These findings can support organizations in making informed decisions related to inventory management, pricing strategies, marketing campaigns, logistics optimization, and customer relationship management.
#
# The use of interactive Plotly visualizations enhanced data interpretation by allowing dynamic exploration of business metrics. Overall, this project demonstrates how data analytics can convert raw transactional data into actionable insights that drive strategic decision-making and improve business performance.
